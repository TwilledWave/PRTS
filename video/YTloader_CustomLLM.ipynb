# %%
import configparser, os, re
config = configparser.ConfigParser()
config.read('./keys.ini')
os.environ['GOOGLE_API_KEY'] = config['GOOGLE']['GOOGLE_API_KEY']
os.environ['GOOGLE_CSE_ID'] = config['GOOGLE']['GOOGLE_CSE_ID']
openai_api_key = config['OPENAI']['OPENAI_API_KEY']
os.environ['OPENAI_API_KEY'] = openai_api_key

# %%
from typing import Any, List, Mapping, Optional
from langchain.llms.base import LLM
from langchain.callbacks.manager import CallbackManagerForLLMRun
import requests

class CustomLLM2(LLM):
    @property
    def _llm_type(self) -> str:
        return "custom"

    def _call(self, prompt: str, stop: Optional[List[str]] = None) -> str:
        if isinstance(stop, list):
            stop = stop + ["\n###","\nObservation:","\n问题","\nQuestion:"]
        HOST = 'localhost:5000'
        URI = f'http://{HOST}/v1/chat/completions'

        response = requests.post(
            URI,
            json={
                "messages": [
                {
                    "role": "user",
                    "content": prompt
                  }
                ],
                "mode": "instruct",
                "instruction_template": "Alpaca",
            },
        )
        response.raise_for_status()
        return response.json()['choices'][0]['message']['content']
  
    @property
    def _identifying_params(self) -> Mapping[str, Any]:
        """Get the identifying parameters."""
        return {}

#use one 1 chain to summary the story dialogue from main page content of the URL
def story_summary_stuff(docs, prompt_template = ""):
    #input: docs of the web page
    from langchain.chains.llm import LLMChain
    from langchain.prompts import PromptTemplate
    from langchain.chains.combine_documents.stuff import StuffDocumentsChain
    # Define prompt
    if prompt_template == "":
        prompt_template = """The text below is the subtitle of a video about US stock market. Summarize it. 
        List the major sections of the video with time stamp.
        Example output:
        Overall summary of the video
        Time Stamp1: Summary1
        Time Stamp2: Summary2
        ...
        "{subtitle}"
        Output:"""
    prompt = PromptTemplate.from_template(prompt_template)

    # Define LLM chain
    #llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-16k")
    llm_chain = LLMChain(llm=llm, prompt=prompt)

    # Define StuffDocumentsChain
    stuff_chain = StuffDocumentsChain(
        llm_chain=llm_chain, document_variable_name="subtitle"
    )
    
    return stuff_chain.run(docs)

#youtube loader and return docs for the transcript with time stamps
def loader(link:str, language=["zh"], db_loc = "./cache/YTDBT", overwrite = False):
    #load video info from link
    from langchain.document_loaders import YoutubeLoader
    try:
        loader = YoutubeLoader.from_youtube_url(
            link, add_video_info=True, language=language
        )
        docs = loader.load()
    except Exception as e:
        print(e)
        return(None);
        
    #check whether the vid is already in the DB
    this_id = docs[0].metadata['source']
    from langchain.vectorstores import Chroma
    from langchain.embeddings import OpenAIEmbeddings
    db = Chroma(persist_directory=db_loc, embedding_function=OpenAIEmbeddings())
    tmp = db.get()['ids']
    #this_db_list = [x.split("_")[0] for x in tmp]
    #this_db_set = set(this_db_list)
    this_db_set = set(tmp)
    if this_id in this_db_set:
        if overwrite == False:
            return(link+" link already in the db, skip");
    print("adding link "+link);
            
    #format the transcript into SRT
    from youtube_transcript_api import YouTubeTranscriptApi
    from youtube_transcript_api.formatters import SRTFormatter
    transcript = YouTubeTranscriptApi.get_transcript(docs[0].metadata['source'],languages=language)
    formatter = SRTFormatter()
    srt_formatted = formatter.format_transcript(transcript)
    with open("./cache/Output.srt", "w", encoding="utf-8") as text_file:
        text_file.write(srt_formatted)
    
    #summarize the SRT with time stamps
    from langchain.chat_models import ChatOpenAI
    #llm = ChatOpenAI(temperature=0, model_name="gpt-4-1106-preview")
    from langchain.docstore.document import Document
    output_srt = Document(page_content="Title: "+docs[0].metadata['title']+" \nSRT: "+srt_formatted, metadata=docs[0].metadata);
    res = story_summary_stuff([output_srt])
    
    #write the summary into DB
    from langchain.embeddings import OpenAIEmbeddings
    from langchain.docstore.document import Document
    output_doc = Document(page_content=res, metadata=docs[0].metadata);
    db.add_documents([output_doc], ids = [docs[0].metadata['source']])
    return(output_doc)

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(temperature=0, model_name="gpt-4o")
#llm = CustomLLM2()
res = loader("https://www.youtube.com/watch?v=8Y6k3z-c3oc&list=PLs8TZNEg0Ubi06d-yWj88kC8Wk5zsMANU&index=3&ab_channel=TwilledWave",language=["en","zh-Hant"], db_loc = "./cache/test", overwrite = True)
print(res.page_content)
# Out:
# adding link https://www.youtube.com/watch?v=8Y6k3z-c3oc&list=PLs8TZNEg0Ubi06d-yWj88kC8Wk5zsMANU&index=3&ab_channel=TwilledWave
# **Overall summary of the video:**
# The video appears to be a dramatic narrative involving a doctor who visits a remote village to provide medical assistance. The villagers, suffering from various ailments and hardships, view the doctor as a savior. The doctor, however, struggles with the villagers' expectations and the harsh realities of their situation. The story explores themes of hope, disillusionment, and the limitations of medical intervention in the face of systemic issues.
#
# **Major sections of the video with time stamps:**
#
# **00:00:00 - 00:00:02:** Introduction and gratitude expressed to the doctor for saving a life.
#
# **00:00:02 - 00:00:05:** The doctor is advised to keep quiet and let a child rest to avoid recurring illness.
#
# **00:00:05 - 00:00:08:** Discussion about payment for the doctor's services, which the doctor refuses.
#
# **00:00:08 - 00:00:10:** The doctor expresses a sense of duty and shame if concerned about material needs.
#
# **00:00:10 - 00:00:12:** The doctor is offered water as a gesture of gratitude.
#
# **00:00:12 - 00:00:16:** The doctor is asked for proof of identity and materials to go to another village.
#
# **00:00:16 - 00:00:18:** The doctor explains the urgency of delivering medicine to the village.
#
# **00:00:18 - 00:00:20:** The doctor is perceived as a stranger with an exotic accent.
#
# **00:00:20 - 00:00:22:** The doctor insists on the importance of delivering medicine.
#
# **00:00:22 - 00:00:24:** The doctor is questioned about being a spy.
#
# **00:00:24 - 00:00:27:** The doctor explains the lack of medical services in the village.
#
# **00:00:27 - 00:00:28:** The doctor reassures the villagers of his intentions.
#
# **00:00:28 - 00:00:31:** The doctor is asked to prove his loyalty by spitting on a portrait.
#
# **00:00:31 - 00:00:34:** The doctor arrives at the village and is warmly welcomed.
#
# **00:00:34 - 00:00:38:** The doctor distributes medicine and performs surgeries.
#
# **00:00:38 - 00:00:41:** The doctor advises villagers on health and nutrition.
#
# **00:00:41 - 00:00:43:** The doctor is thanked for his services.
#
# **00:00:43 - 00:00:45:** The doctor discusses the villagers' hardships and the need for medical services.
#
# **00:00:45 - 00:00:48:** The doctor reflects on the villagers' respect and expectations.
#
# **00:00:48 - 00:00:50:** The doctor is asked to take the villagers to a better place.
#
# **00:00:50 - 00:00:54:** The doctor struggles with the villagers' expectations and his own limitations.
#
# **00:00:54 - 00:00:57:** The doctor destroys a portrait symbolizing false hope.
#
# **00:00:57 - 00:01:00:** The doctor emphasizes the need for realistic expectations.
#
# **00:01:00 - 00:01:02:** The doctor prepares to leave the village, urging the villagers to find their own path.
#
# **00:01:02 - 00:01:05:** The doctor reflects on his role and the villagers' future.
#
# **00:01:05 - 00:01:08:** The doctor discusses the importance of self-reliance and realistic goals.
#
# **00:01:08 - 00:01:10:** The doctor departs, leaving the villagers to contemplate their future.
#
# **00:01:10 - 00:01:12:** The doctor is thanked for his service and leaves the village.
#
# **00:01:12 - 00:01:14:** The doctor reflects on the experience and the villagers' respect.
#
# **00:01:14 - 00:01:17:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:01:17 - 00:01:20:** The doctor departs, leaving the villagers to find their own path.
#
# **00:01:20 - 00:01:22:** The doctor reflects on the experience and the villagers' respect.
#
# **00:01:22 - 00:01:25:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:01:25 - 00:01:28:** The doctor departs, leaving the villagers to find their own path.
#
# **00:01:28 - 00:01:30:** The doctor reflects on the experience and the villagers' respect.
#
# **00:01:30 - 00:01:32:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:01:32 - 00:01:35:** The doctor departs, leaving the villagers to find their own path.
#
# **00:01:35 - 00:01:37:** The doctor reflects on the experience and the villagers' respect.
#
# **00:01:37 - 00:01:40:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:01:40 - 00:01:43:** The doctor departs, leaving the villagers to find their own path.
#
# **00:01:43 - 00:01:45:** The doctor reflects on the experience and the villagers' respect.
#
# **00:01:45 - 00:01:48:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:01:48 - 00:01:50:** The doctor departs, leaving the villagers to find their own path.
#
# **00:01:50 - 00:01:52:** The doctor reflects on the experience and the villagers' respect.
#
# **00:01:52 - 00:01:55:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:01:55 - 00:01:57:** The doctor departs, leaving the villagers to find their own path.
#
# **00:01:57 - 00:02:00:** The doctor reflects on the experience and the villagers' respect.
#
# **00:02:00 - 00:02:02:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:02:02 - 00:02:05:** The doctor departs, leaving the villagers to find their own path.
#
# **00:02:05 - 00:02:08:** The doctor reflects on the experience and the villagers' respect.
#
# **00:02:08 - 00:02:10:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:02:10 - 00:02:12:** The doctor departs, leaving the villagers to find their own path.
#
# **00:02:12 - 00:02:14:** The doctor reflects on the experience and the villagers' respect.
#
# **00:02:14 - 00:02:17:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:02:17 - 00:02:20:** The doctor departs, leaving the villagers to find their own path.
#
# **00:02:20 - 00:02:22:** The doctor reflects on the experience and the villagers' respect.
#
# **00:02:22 - 00:02:25:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:05:30 - 00:05:32:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:05:32 - 00:05:35:** The doctor departs, leaving the villagers to find their own path.
#
# **00:05:35 - 00:05:37:** The doctor reflects on the experience and the villagers' respect.
#
# **00:05:37 - 00:05:40:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:05:40 - 00:05:43:** The doctor departs, leaving the villagers to find their own path.
#
# **00:05:43 - 00:05:45:** The doctor reflects on the experience and the villagers' respect.
#
# **00:05:45 - 00:05:48:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:05:48 - 00:05:50:** The doctor departs, leaving the villagers to find their own path.
#
# **00:05:50 - 00:05:52:** The doctor reflects on the experience and the villagers' respect.
#
# **00:05:52 - 00:05:55:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:05:55 - 00:05:57:** The doctor departs, leaving the villagers to find their own path.
#
# **00:05:57 - 00:06:00:** The doctor reflects on the experience and the villagers' respect.
#
# **00:06:00 - 00:06:02:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:06:02 - 00:06:05:** The doctor departs, leaving the villagers to find their own path.
#
# **00:06:05 - 00:06:08:** The doctor reflects on the experience and the villagers' respect.
#
# **00:06:08 - 00:06:10:** The doctor emphasizes the importance of realistic expectations and self-reliance.
#
# **00:06:10 - 00:06:12

# %%
from pytube import Playlist
p = Playlist('https://www.youtube.com/playlist?list=PLweTl9OQEsJhOM8W6ZAigP7eJxBU_yQM6')
for url in p.video_urls:
    res = loader(url,["en"])
    print(res.metadata['title'])
# Out:
# adding link https://www.youtube.com/watch?v=-iHseGn2LhQ
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 p = Playlist('https://www.youtube.com/playlist?list=PLweTl9OQEsJhOM8W6ZAigP7eJxBU_yQM6')
#       3 for url in p.video_urls:
# ----> 4     res = loader(url,["en"])
#       5     print(res.metadata['title'])
#
# Cell In[2], line 109, in loader(link, language, db_loc, overwrite)
#     107 from langchain.docstore.document import Document
#     108 output_srt = Document(page_content="Title: "+docs[0].metadata['title']+" \nSRT: "+srt_formatted, metadata=docs[0].metadata);
# --> 109 res = story_summary_stuff([output_srt])
#     111 #write the summary into DB
#     112 from langchain.embeddings import OpenAIEmbeddings
#
# Cell In[2], line 66, in story_summary_stuff(docs, prompt_template)
#      61 # Define StuffDocumentsChain
#      62 stuff_chain = StuffDocumentsChain(
#      63     llm_chain=llm_chain, document_variable_name="subtitle"
#      64 )
# ---> 66 return stuff_chain.run(docs)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:487, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     485     if len(args) != 1:
#     486         raise ValueError("`run` supports only one positional argument.")
# --> 487     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     488         _output_key
#     489     ]
#     491 if kwargs and not args:
#     492     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     493         _output_key
#     494     ]
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\combine_documents\base.py:105, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     103 # Other keys are assumed to be needed for LLM prediction
#     104 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 105 output, extra_return_dict = self.combine_docs(
#     106     docs, callbacks=_run_manager.get_child(), **other_keys
#     107 )
#     108 extra_return_dict[self.output_key] = output
#     109 return extra_return_dict
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\combine_documents\stuff.py:171, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     169 inputs = self._get_inputs(docs, **kwargs)
#     170 # Call predict on the LLM.
# --> 171 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\llm.py:255, in LLMChain.predict(self, callbacks, **kwargs)
#     240 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     241     """Format prompt with kwargs and pass to LLM.
#     242
#     243     Args:
#    (...)
#     253             completion = llm.predict(adjective="funny")
#     254     """
# --> 255     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\llm.py:91, in LLMChain._call(self, inputs, run_manager)
#      86 def _call(
#      87     self,
#      88     inputs: Dict[str, Any],
#      89     run_manager: Optional[CallbackManagerForChainRun] = None,
#      90 ) -> Dict[str, str]:
# ---> 91     response = self.generate([inputs], run_manager=run_manager)
#      92     return self.create_outputs(response)[0]
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\llm.py:101, in LLMChain.generate(self, input_list, run_manager)
#      99 """Generate LLM result from inputs."""
#     100 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 101 return self.llm.generate_prompt(
#     102     prompts,
#     103     stop,
#     104     callbacks=run_manager.get_child() if run_manager else None,
#     105     **self.llm_kwargs,
#     106 )
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\llms\base.py:486, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     478 def generate_prompt(
#     479     self,
#     480     prompts: List[PromptValue],
#    (...)
#     483     **kwargs: Any,
#     484 ) -> LLMResult:
#     485     prompt_strings = [p.to_string() for p in prompts]
# --> 486     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\llms\base.py:621, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, **kwargs)
#     612         raise ValueError(
#     613             "Asked to cache, but no cache found at `langchain.cache`."
#     614         )
#     615     run_managers = [
#     616         callback_manager.on_llm_start(
#     617             dumpd(self), [prompt], invocation_params=params, options=options
#     618         )[0]
#     619         for callback_manager, prompt in zip(callback_managers, prompts)
#     620     ]
# --> 621     output = self._generate_helper(
#     622         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     623     )
#     624     return output
#     625 if len(missing_prompts) > 0:
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\llms\base.py:523, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     521     for run_manager in run_managers:
#     522         run_manager.on_llm_error(e)
# --> 523     raise e
#     524 flattened_outputs = output.flatten()
#     525 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\llms\base.py:510, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     500 def _generate_helper(
#     501     self,
#     502     prompts: List[str],
#    (...)
#     506     **kwargs: Any,
#     507 ) -> LLMResult:
#     508     try:
#     509         output = (
# --> 510             self._generate(
#     511                 prompts,
#     512                 stop=stop,
#     513                 # TODO: support multiple run managers
#     514                 run_manager=run_managers[0] if run_managers else None,
#     515                 **kwargs,
#     516             )
#     517             if new_arg_supported
#     518             else self._generate(prompts, stop=stop)
#     519         )
#     520     except (KeyboardInterrupt, Exception) as e:
#     521         for run_manager in run_managers:
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\llms\base.py:1002, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#     997 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#     998 for prompt in prompts:
#     999     text = (
#    1000         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1001         if new_arg_supported
# -> 1002         else self._call(prompt, stop=stop, **kwargs)
#    1003     )
#    1004     generations.append([Generation(text=text)])
#    1005 return LLMResult(generations=generations)
#
# Cell In[2], line 30, in CustomLLM2._call(self, prompt, stop)
#      15 URI = f'http://{HOST}/v1/chat/completions'
#      17 response = requests.post(
#      18     URI,
#      19     json={
#    (...)
#      28     },
#      29 )
# ---> 30 response.raise_for_status()
#      31 return response.json()['choices'][0]['message']['content']
#
# File ~\anaconda3\envs\lang\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://localhost:5000/v1/chat/completions

# %%
p.video_urls
# Out:
# ['https://www.youtube.com/watch?v=zCf87ABhqpU', 'https://www.youtube.com/watch?v=-iHseGn2LhQ', 'https://www.youtube.com/watch?v=Oh3QdmodNK8']

# %%
#llm = CustomLLM2()
db_loc = "./cache/stock"
Channels = ["https://www.youtube.com/watch?v=0p4EGTMBGoM&list=UULFH-_Z7YSk4QTFmXbYSSBB4w&ab_channel=MikeSwartz",
            "https://www.youtube.com/watch?v=PY2dh6RdfIU&list=UULFoMzWLaPjDJBbipihD694pQ&ab_channel=StockMoe",
            "https://www.youtube.com/watch?v=hE-k_SUKGCs&list=UULFFCEuCsyWP0YkP3CZ3Mr01Q&ab_channel=ThePlainBagel",
            "https://www.youtube.com/watch?v=t1Ic3f8q-o4&list=UULFFhJ8ZFg9W4kLwFTBBNIjOw&ab_channel=NaNa%E8%AF%B4%E7%BE%8E%E8%82%A1",
            "https://www.youtube.com/watch?v=tLLzdsLTDPs&list=UULF7kCeZ53sli_9XwuQeFxLqw&ab_channel=TickerSymbol%3AYOU",
            "https://www.youtube.com/watch?v=7BnzPu6LbMY&list=UULFyqlbzLoYtpqDXwRI9Yh5LA&ab_channel=BWB-BusinessWithBrian",
           ]

from pytube import Playlist
text = ""
for c in Channels: 
    p = Playlist(c)
    url = p.video_urls[0]
    res = loader(url,language=["en","zh-Hant"],db_loc = "./cache/stock")
    if (type(res)==str) | (res == None):
        print(res)
    else:
        print(res.metadata['title'])
        print(res.page_content)
        text = text +"\n" + res.page_content
# Out:
# adding link https://www.youtube.com/watch?v=bjBs9QDz_XI
# My AlgoBox Indicators And Settings
# ### Overall summary of the video
# The video provides a detailed overview of the speaker's AlgoBox indicators and settings used for trading in the US stock market. It covers various charts, indicators, and settings, explaining how they are configured and utilized to optimize trading performance.
#
# ### Major sections of the video with time stamps
#
# **00:00:00 - 00:00:01**: Introduction to the video and common questions from traders.
#
# **00:00:01 - 00:00:04**: Overview of the AlgoBox settings and charts used.
#
# **00:00:04 - 00:00:06**: Explanation of the 89 range chart and its significance.
#
# **00:00:06 - 00:00:08**: Introduction to the data series and loading bars.
#
# **00:00:08 - 00:00:11**: Discussion on keeping the machine light for better performance.
#
# **00:00:11 - 00:00:13**: Indicators used on the 89 range chart.
#
# **00:00:13 - 00:00:15**: Details on the golden ropes indicator.
#
# **00:00:15 - 00:00:18**: Explanation of the ultimate OBOS and FIB ELOD dots.
#
# **00:00:18 - 00:00:21**: Settings for swing strength and harmonic patterns.
#
# **00:00:21 - 00:00:24**: Overview of the main charts per instrument.
#
# **00:00:24 - 00:00:28**: Configuration of the wave charts and their usage.
#
# **00:00:28 - 00:00:30**: Data series settings for the 24 range chart.
#
# **00:00:30 - 00:00:32**: Indicators on the 24 range chart.
#
# **00:00:32 - 00:00:34**: Delta flagging Pro and its settings.
#
# **00:00:34 - 00:00:37**: FIB ELOD Pro settings and performance optimization.
#
# **00:00:37 - 00:00:40**: Flow master bubbles and their configuration.
#
# **00:00:40 - 00:00:42**: Harmonic pattern Pro and impulse leg settings.
#
# **00:00:42 - 00:00:44**: Ultimate OBOS and audio box settings.
#
# **00:00:44 - 00:00:46**: Alpha Mega settings and their adjustments.
#
# **00:00:46 - 00:00:48**: Mac V chart and its indicators.
#
# **00:00:48 - 00:00:50**: Data series settings for the Mac V chart.
#
# **00:00:50 - 00:00:52**: Delta flagging Pro and favorable direction indicators.
#
# **00:00:52 - 00:00:54**: FIB OT Pro and flow master bubbles settings.
#
# **00:00:54 - 00:00:56**: Harmonic patterns and ultimate OBOS on the Mac V chart.
#
# **00:00:56 - 00:00:58**: Mac V entry system and deviation lines.
#
# **00:00:58 - 00:01:00**: Ripple chart settings and indicators.
#
# **00:01:00 - 00:01:02**: Data series settings for the Ripple chart.
#
# **00:01:02 - 00:01:04**: SMLK lines and speedometer settings.
#
# **00:01:04 - 00:01:06**: Open high low settings and button panel configuration.
#
# **00:01:06 - 00:01:08**: Delta flagging and FIB ELOD Pro settings.
#
# **00:01:08 - 00:01:10**: Alpha Mega settings and flow master crosses.
#
# **00:01:10 - 00:01:12**: Harmonic pattern Pro and J Hooks settings.
#
# **00:01:12 - 00:01:14**: Golden ropes and Enigma bot panel settings.
#
# **00:01:14 - 00:01:16**: Bid ask lines and their benefits.
#
# **00:01:16 - 00:01:18**: AlgoBox position manager and button settings.
#
# **00:01:18 - 00:01:21**: Conclusion and recommendation to use the link for the best deal on AlgoBox.
# adding link https://www.youtube.com/watch?v=iXPUEXrRHuA
# GAMESTOP JUST DID WHAT?🔥🚀 GAMESTOP AND AMC PRICE PREDICTION NEWS! COME ON!!!
# **Overall summary of the video:**
# The video discusses recent developments and price predictions for GameStop and AMC stocks. It covers the impact of GameStop's decision to sell additional shares, the resulting stock price movements, and the broader implications for investors. The video also touches on the similarities between the trading patterns of GameStop and AMC, and provides technical analysis and predictions for both stocks.
#
# **Time Stamps and Summaries:**
#
# **00:00:00 - 00:00:03:** Introduction to the topic of GameStop and AMC.
#
# **00:00:03 - 00:00:05:** Mention of the repetitive nature of events similar to AMC.
#
# **00:00:05 - 00:00:07:** Brief overview of the video content.
#
# **00:00:07 - 00:00:09:** Introduction to the speaker's portfolio and crypto investments.
#
# **00:00:09 - 00:00:11:** Discussion on the speaker's position in the crypto space.
#
# **00:00:11 - 00:00:13:** Mention of new viewers and the speaker's appearance on CNBC.
#
# **00:00:13 - 00:00:16:** Discussion on Faraday and its similarities to AMC.
#
# **00:00:16 - 00:00:19:** Analysis of Faraday's stock performance.
#
# **00:00:19 - 00:00:22:** Transition to discussing GameStop and AMC.
#
# **00:00:22 - 00:00:25:** Mention of GameStop's recent stock movements.
#
# **00:00:25 - 00:00:28:** Discussion on GameStop's decision to sell additional shares.
#
# **00:00:28 - 00:00:30:** Analysis of the impact of GameStop's decision on its stock price.
#
# **00:00:30 - 00:00:32:** Mention of the speaker's Patreon and charting tools.
#
# **00:00:32 - 00:00:35:** Introduction to the technical analysis of GameStop.
#
# **00:00:35 - 00:00:36:** Discussion on GameStop's stock performance and predictions.
#
# **00:00:36 - 00:00:39:** Analysis of GameStop's stock movements and potential recovery.
#
# **00:00:39 - 00:00:40:** Mention of Wall Street's preparedness for recent events.
#
# **00:00:40 - 00:00:44:** Discussion on Bill Gross's investment strategy and its impact.
#
# **00:00:44 - 00:00:45:** Analysis of GameStop's stock performance and predictions.
#
# **00:00:45 - 00:00:48:** Technical analysis of GameStop's stock chart.
#
# **00:00:48 - 00:00:50:** Discussion on potential recovery and future movements of GameStop.
#
# **00:00:50 - 00:00:53:** Mention of the speaker's technical indicators and tools.
#
# **00:00:53 - 00:00:55:** Analysis of GameStop's stock movements and potential recovery.
#
# **00:00:55 - 00:00:58:** Discussion on the potential for a relief rally in GameStop's stock.
#
# **00:00:58 - 00:01:01:** Mention of the speaker's technical analysis tools and predictions.
#
# **00:01:01 - 00:01:05:** Transition to discussing AMC's stock performance and predictions.
#
# **00:01:05 - 00:01:06:** Analysis of AMC's stock movements and potential recovery.
#
# **00:01:06 - 00:01:08:** Discussion on the similarities between GameStop and AMC.
#
# **00:01:08 - 00:01:10:** Technical analysis of AMC's stock chart.
#
# **00:01:10 - 00:01:11:** Discussion on potential recovery and future movements of AMC.
#
# **00:01:11 - 00:01:13:** Mention of Wall Street's involvement in AMC's stock movements.
#
# **00:01:13 - 00:01:15:** Analysis of AMC's stock movements and potential recovery.
#
# **00:01:15 - 00:01:16:** Discussion on the potential for a relief rally in AMC's stock.
#
# **00:01:16 - 00:01:19:** Mention of the speaker's technical analysis tools and predictions.
#
# **00:01:19 - 00:01:21:** Analysis of AMC's stock movements and potential recovery.
#
# **00:01:21 - 00:01:23:** Discussion on the potential for a relief rally in AMC's stock.
#
# **00:01:23 - 00:01:25:** Mention of the speaker's technical analysis tools and predictions.
#
# **00:01:25 - 00:01:28:** Analysis of AMC's stock movements and potential recovery.
#
# **00:01:28 - 00:01:30:** Discussion on the potential for a relief rally in AMC's stock.
#
# **00:01:30 - 00:01:32:** Mention of the speaker's technical analysis tools and predictions.
#
# **00:06:16 - 00:06:19:** Analysis of AMC's stock movements and potential recovery.
#
# **00:06:19 - 00:06:21:** Discussion on the potential for a relief rally in AMC's stock.
#
# **00:06:21 - 00:06:25:** Mention of the speaker's technical analysis tools and predictions.
#
# **00:06:25 - 00:06:28:** Analysis of AMC's stock movements and potential recovery.
#
# **00:06:28 - 00:06:30:** Discussion on the potential for a relief rally in AMC's stock.
#
# **00:06:30 - 00:06:32:**
# adding link https://www.youtube.com/watch?v=ycsVS5Me-2o
# What Just Happened With GameStop?
# **Overall summary of the video:**
# The video discusses the recent resurgence of meme stocks, particularly GameStop, and the factors contributing to their volatile performance. It delves into the role of key figures like Keith Gill, the impact of social media, and the speculative nature of the stock market. The video also provides a cautious perspective on the sustainability of such rallies and the fundamental health of the companies involved.
#
# **Major sections of the video with time stamps:**
#
# **00:00:00 - 00:00:07**: Introduction to the resurgence of meme stocks, focusing on GameStop's recent performance.
#
# **00:00:07 - 00:00:22**: Overview of GameStop's stock performance, including significant intraday jumps and overall gains.
#
# **00:00:22 - 00:00:35**: Introduction of Keith Gill (Roaring Kitty) and his influence on the GameStop rally.
#
# **00:00:35 - 00:00:52**: Keith Gill's recent social media activity and its impact on the stock market.
#
# **00:00:52 - 00:01:01**: Discussion on the involvement of other influencers and public figures in promoting GameStop.
#
# **00:01:01 - 00:01:24**: Cautionary note on the speculative nature of the rally and the unpredictability of stock prices.
#
# **00:01:24 - 00:01:41**: Explanation of the initial trigger for the recent rally and the resulting trading volume.
#
# **00:01:41 - 00:02:00**: Details on trading halts and technical issues faced by brokers during the rally.
#
# **00:02:00 - 00:02:20**: Mention of other meme stocks like AMC and Blackberry experiencing similar surges.
#
# **00:02:20 - 00:02:40**: Discussion on hedge funds' losses and the potential for a short squeeze.
#
# **00:02:40 - 00:03:00**: Explanation of a short squeeze and its mechanics.
#
# **00:03:00 - 00:03:20**: Analysis of the fundamental health of GameStop and its financial performance.
#
# **00:03:20 - 00:03:40**: Discussion on GameStop's revenue, profit margins, and business strategy.
#
# **00:03:40 - 00:04:00**: Comparison of GameStop's valuation to other companies and the gap between its stock price and fundamentals.
#
# **00:04:00 - 00:04:20**: Highlighting the speculative nature of the current rally and the risks involved.
#
# **00:04:20 - 00:04:40**: Analysis of short interest in GameStop and its impact on the potential for a short squeeze.
#
# **00:04:40 - 00:05:00**: Discussion on the role of direct registration and institutional ownership in the stock's performance.
#
# **00:05:00 - 00:05:20**: Mention of the SEC report on the 2021 GameStop rally and its findings.
#
# **00:05:20 - 00:05:40**: Analysis of the role of institutional investors in the recent rally.
#
# **00:05:40 - 00:06:00**: Discussion on the speculative theories surrounding the stock and their potential impact.
#
# **00:06:00 - 00:06:20**: Mention of past speculative theories that did not pan out, such as those involving Bed Bath & Beyond.
#
# **00:06:20 - 00:06:40**: Cautionary note on the risks of following speculative theories and the importance of understanding market complexities.
#
# **00:06:40 - 00:07:00**: Final thoughts on the speculative nature of meme stocks and the importance of being cautious.
#
# **00:07:00 - 00:07:20**: Conclusion and invitation for viewers to share their thoughts and engage in discussion.
#
# **00:07:20 - 00:07:40**: Reminder to like, subscribe, and stay safe in the market.
# adding link https://www.youtube.com/watch?v=rFOR_wSPd8A
# 贾会计的镰刀太凶残了！NaNa说美股(2024.05.17)
# **Overall summary of the video:**
# The video provides an analysis of the US stock market on May 17, 2024, discussing the day's market movements, key events, and notable stock performances. It covers the Dow Jones Industrial Average reaching a historic milestone, the impact of Federal Reserve comments on inflation and interest rates, and the performance of various stocks including meme stocks, tech stocks, and Chinese stocks.
#
# **Major sections of the video with time stamps:**
#
# **00:00:13 - 00:00:14:** Introduction to the video.
#
# **00:00:14 - 00:00:17:** Date and day of the week.
#
# **00:00:17 - 00:00:19:** Overview of the day's market, noting a lack of significant movement.
#
# **00:00:19 - 00:00:23:** Brief dip in the market due to comments from Federal Reserve Governor Bowman.
#
# **00:00:23 - 00:00:27:** Market quickly rebounded after the dip.
#
# **00:00:27 - 00:00:29:** Bowman's willingness to support rate hikes if inflation stagnates.
#
# **00:00:29 - 00:00:33:** The market's quick recovery and minimal impact from Bowman's comments.
#
# **00:00:33 - 00:00:36:** Dow Jones Industrial Average closes above 40,000 points for the first time.
#
# **00:00:36 - 00:00:38:** Light trading volume despite the milestone.
#
# **00:00:38 - 00:00:44:** Dow's 12-month forward P/E ratio at 18.4, not cheap but with room for growth.
#
# **00:00:44 - 00:00:46:** Previous day's market performance and concerns about a double top.
#
# **00:00:46 - 00:00:54:** Today's milestone alleviates previous concerns and boosts bullish sentiment.
#
# **00:00:54 - 00:01:02:** Comparison of Dow's P/E ratio with S&P and Nasdaq, indicating potential for further growth.
#
# **00:01:02 - 00:01:03:** Historical P/E ratio of Dow at the start of the current rally.
#
# **00:01:03 - 00:01:07:** S&P 500's current pause and bullish control.
#
# **00:01:07 - 00:01:09:** S&P 500's potential for continued upward trend.
#
# **00:01:09 - 00:01:14:** Key levels for S&P 500 and potential for short-term pullbacks.
#
# **00:01:14 - 00:01:16:** Nasdaq's slight decline due to rising bond yields.
#
# **00:01:16 - 00:01:19:** Increased trading volume in Nasdaq yesterday.
#
# **00:01:19 - 00:01:24:** Expectation of sideways movement in Nasdaq until Nvidia's earnings report.
#
# **00:01:24 - 00:01:29:** Key support and resistance levels for Nasdaq 100.
#
# **00:01:29 - 00:01:36:** Market's reaction to CPI data and Federal Reserve's hawkish comments.
#
# **00:01:36 - 00:01:41:** Analysts' optimistic outlook for US stocks despite recent pullback.
#
# **00:01:41 - 00:01:46:** Meme stocks' mixed performance, with Reddit's significant gain.
#
# **00:01:46 - 00:01:49:** OpenAI's partnership with Reddit boosts Reddit's stock.
#
# **00:01:49 - 00:01:53:** GameStop's Q1 sales miss expectations, leading to stock sell-off.
#
# **00:01:53 - 00:01:57:** GameStop's stock volatility and retail investors' shift to penny stocks.
#
# **00:01:57 - 00:02:00:** CRKN and GWAV's recent stock performance.
#
# **00:02:00 - 00:02:05:** Faraday Future's (FFIE) dramatic stock surge and subsequent decline.
#
# **00:02:05 - 00:02:09:** Factors contributing to FFIE's stock movement.
#
# **00:02:09 - 00:02:13:** FFIE's stock volatility and potential delisting risk.
#
# **00:02:13 - 00:02:18:** General advice on trading meme and penny stocks.
#
# **00:02:18 - 00:02:22:** AMD's stock performance and impact from Nvidia.
#
# **00:02:22 - 00:02:27:** AMD's stock closing below the 50-day moving average.
#
# **00:02:27 - 00:02:33:** Microsoft's plan to offer AMD's AI chips through Azure.
#
# **00:02:33 - 00:02:37:** Take-Two's earnings report and delay of GTA VI.
#
# **00:02:37 - 00:02:45:** Take-Two's financial outlook and stock performance.
#
# **00:02:45 - 00:02:50:** Chinese stocks' strong performance due to domestic real estate policies.
#
# **00:02:50 - 00:02:56:** Alibaba's stock performance and Citron Research's bullish stance.
#
# **00:02:56 - 00:03:01:** Historical context of Citron's previous bullish calls.
#
# **00:03:01 - 00:03:05:** Alibaba's technical analysis and recent stock movement.
#
# **00:03:05 - 00:03:10:** Institutional investors' increased holdings in Alibaba.
#
# **00:03:10 - 00:03:15:** David Tepper's hedge fund's significant holdings in Chinese stocks.
#
# **00:03:15 - 00:03:17:** Michael Burry's investments in Chinese stocks.
#
# **00:03:17 - 00:03:22:** Bank of America's updated price target for Alibaba.
#
# **00:03:22 - 00:03:27:** Advice on managing positions in a bullish market.
#
# **00:03:27 - 00:03:31:** Tencent's stock performance and US politicians' investments.
#
# **00:03:31 - 00:03:36:** US politicians' stock trading activities and performance.
#
# **00:03:36 - 00:03:41:** Conclusion and final thoughts on the market.
# adding link https://www.youtube.com/watch?v=RHOYo-mbjEk
# Google Reveals CRAZY New AI to CRUSH OpenAI GPT4-o (Supercut)
# ### Overall summary of the video
# The video discusses Google's advancements in AI, particularly focusing on the Gemini model, which is designed to be multimodal and capable of handling long contexts. It highlights various applications of Gemini in Google Search, Google Photos, and other Google services, demonstrating how AI is transforming user experiences. The video also introduces new hardware and software innovations aimed at enhancing AI capabilities and efficiency.
#
# ### Major sections of the video with time stamps
#
# **00:00:00 - 00:00:02**: Introduction to Gemini, a Frontier Model.
#
# **00:00:02 - 00:00:06**: Plans for Gemini being natively multimodal.
#
# **00:00:06 - 00:00:08**: Gemini's ability to reason across various inputs.
#
# **00:00:08 - 00:00:11**: Turning any input into any output.
#
# **00:00:11 - 00:00:15**: Introduction of Gemini 1.5 Pro.
#
# **00:00:15 - 00:00:18**: Breakthrough in long context handling.
#
# **00:00:18 - 00:00:21**: Gemini's impact on Google Search.
#
# **00:00:21 - 00:00:24**: Testing and user satisfaction with the new search experience.
#
# **00:00:24 - 00:00:28**: Launching AI overviews in the US.
#
# **00:00:28 - 00:00:30**: Example of using Google Photos with Gemini.
#
# **00:00:30 - 00:00:32**: Searching for license plate numbers in photos.
#
# **00:00:32 - 00:00:35**: Deeper search capabilities in Google Photos.
#
# **00:00:35 - 00:00:38**: Gemini's ability to recognize different contexts.
#
# **00:00:38 - 00:00:40**: Rolling out "Ask Photos" feature.
#
# **00:00:40 - 00:00:42**: Expanding the context window to 2 million tokens.
#
# **00:00:42 - 00:00:45**: Multimodality and long context advances.
#
# **00:00:45 - 00:00:48**: Early demo of audio output in Notebook LM.
#
# **00:00:48 - 00:00:50**: Introduction of Notebook LM with Gemini 1.5 Pro.
#
# **00:00:50 - 00:00:54**: Example of a lively science discussion generated by Notebook LM.
#
# **00:00:54 - 00:00:57**: Multimodal capabilities in generating audio discussions.
#
# **00:00:57 - 00:01:00**: Custom examples created by Gemini.
#
# **00:01:00 - 00:01:03**: Introduction of Project Astra by Google DeepMind.
#
# **00:01:03 - 00:01:06**: Vision of building AGI (Artificial General Intelligence).
#
# **00:01:06 - 00:01:09**: Development of agents that understand and respond to complex contexts.
#
# **00:01:09 - 00:01:12**: Enhancements in video and speech input processing.
#
# **00:01:12 - 00:01:15**: Prototype demonstration of AI agents.
#
# **00:01:15 - 00:01:18**: Introduction of Gemini 1.5 Flash for low latency and efficiency.
#
# **00:01:18 - 00:01:21**: Availability of Gemini models in Google AI Studio and Vertex AI.
#
# **00:01:21 - 00:01:24**: Announcement of the sixth generation of TPUs called Trillium.
#
# **00:01:24 - 00:01:27**: Trillium's performance improvements and availability.
#
# **00:01:27 - 00:01:30**: Integration of CPUs and GPUs for various workloads.
#
# **00:01:30 - 00:01:33**: Advances in Google Search with generative AI.
#
# **00:01:33 - 00:01:36**: AI overviews and multi-step reasoning in search.
#
# **00:01:36 - 00:01:39**: AI-organized search results for inspiration.
#
# **00:01:39 - 00:01:42**: Introduction of video-based search queries.
#
# **00:01:42 - 00:01:45**: Live demo of video-based search.
#
# **00:01:45 - 00:01:48**: Gemini's capabilities in workspace applications.
#
# **00:01:48 - 00:01:51**: Automating workflows in Gmail and Drive.
#
# **00:01:51 - 00:01:54**: Customizing Gemini for personal needs with "Gems".
#
# **00:01:54 - 00:01:57**: Trip planning and data analysis features in Gemini.
#
# **00:01:57 - 00:02:00**: AI-powered search and on-device AI in Android.
#
# **00:02:00 - 00:02:03**: Protection against fraud with on-device AI.
#
# **00:02:03 - 00:02:06**: Summary of AI advancements and future possibilities.
#
# **00:02:06 - 00:02:09**: Closing remarks and emphasis on AI's transformative potential.
# adding link https://www.youtube.com/watch?v=gtzFhxug99g
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 16
#      14 p = Playlist(c)
#      15 url = p.video_urls[0]
# ---> 16 res = loader(url,language=["en","zh-Hant"],db_loc = "./cache/stock")
#      17 if (type(res)==str) | (res == None):
#      18     print(res)
#
# Cell In[2], line 109, in loader(link, language, db_loc, overwrite)
#     107 from langchain.docstore.document import Document
#     108 output_srt = Document(page_content="Title: "+docs[0].metadata['title']+" \nSRT: "+srt_formatted, metadata=docs[0].metadata);
# --> 109 res = story_summary_stuff([output_srt])
#     111 #write the summary into DB
#     112 from langchain.embeddings import OpenAIEmbeddings
#
# Cell In[2], line 66, in story_summary_stuff(docs, prompt_template)
#      61 # Define StuffDocumentsChain
#      62 stuff_chain = StuffDocumentsChain(
#      63     llm_chain=llm_chain, document_variable_name="subtitle"
#      64 )
# ---> 66 return stuff_chain.run(docs)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:487, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     485     if len(args) != 1:
#     486         raise ValueError("`run` supports only one positional argument.")
# --> 487     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     488         _output_key
#     489     ]
#     491 if kwargs and not args:
#     492     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     493         _output_key
#     494     ]
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\combine_documents\base.py:105, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     103 # Other keys are assumed to be needed for LLM prediction
#     104 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 105 output, extra_return_dict = self.combine_docs(
#     106     docs, callbacks=_run_manager.get_child(), **other_keys
#     107 )
#     108 extra_return_dict[self.output_key] = output
#     109 return extra_return_dict
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\combine_documents\stuff.py:171, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     169 inputs = self._get_inputs(docs, **kwargs)
#     170 # Call predict on the LLM.
# --> 171 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\llm.py:255, in LLMChain.predict(self, callbacks, **kwargs)
#     240 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     241     """Format prompt with kwargs and pass to LLM.
#     242
#     243     Args:
#    (...)
#     253             completion = llm.predict(adjective="funny")
#     254     """
# --> 255     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\llm.py:91, in LLMChain._call(self, inputs, run_manager)
#      86 def _call(
#      87     self,
#      88     inputs: Dict[str, Any],
#      89     run_manager: Optional[CallbackManagerForChainRun] = None,
#      90 ) -> Dict[str, str]:
# ---> 91     response = self.generate([inputs], run_manager=run_manager)
#      92     return self.create_outputs(response)[0]
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chains\llm.py:101, in LLMChain.generate(self, input_list, run_manager)
#      99 """Generate LLM result from inputs."""
#     100 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 101 return self.llm.generate_prompt(
#     102     prompts,
#     103     stop,
#     104     callbacks=run_manager.get_child() if run_manager else None,
#     105     **self.llm_kwargs,
#     106 )
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chat_models\base.py:414, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     406 def generate_prompt(
#     407     self,
#     408     prompts: List[PromptValue],
#    (...)
#     411     **kwargs: Any,
#     412 ) -> LLMResult:
#     413     prompt_messages = [p.to_messages() for p in prompts]
# --> 414     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chat_models\base.py:309, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, **kwargs)
#     307         if run_managers:
#     308             run_managers[i].on_llm_error(e)
# --> 309         raise e
#     310 flattened_outputs = [
#     311     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     312     for res in results
#     313 ]
#     314 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chat_models\base.py:299, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, **kwargs)
#     296 for i, m in enumerate(messages):
#     297     try:
#     298         results.append(
# --> 299             self._generate_with_cache(
#     300                 m,
#     301                 stop=stop,
#     302                 run_manager=run_managers[i] if run_managers else None,
#     303                 **kwargs,
#     304             )
#     305         )
#     306     except (KeyboardInterrupt, Exception) as e:
#     307         if run_managers:
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chat_models\base.py:446, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     442     raise ValueError(
#     443         "Asked to cache, but no cache found at `langchain.cache`."
#     444     )
#     445 if new_arg_supported:
# --> 446     return self._generate(
#     447         messages, stop=stop, run_manager=run_manager, **kwargs
#     448     )
#     449 else:
#     450     return self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chat_models\openai.py:345, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     343 message_dicts, params = self._create_message_dicts(messages, stop)
#     344 params = {**params, **kwargs}
# --> 345 response = self.completion_with_retry(
#     346     messages=message_dicts, run_manager=run_manager, **params
#     347 )
#     348 return self._create_chat_result(response)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chat_models\openai.py:278, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     274 @retry_decorator
#     275 def _completion_with_retry(**kwargs: Any) -> Any:
#     276     return self.client.create(**kwargs)
# --> 278 return _completion_with_retry(**kwargs)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~\anaconda3\envs\lang\Lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File ~\anaconda3\envs\lang\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\lang\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\lang\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\lang\Lib\site-packages\langchain\chat_models\openai.py:276, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     274 @retry_decorator
#     275 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 276     return self.client.create(**kwargs)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~\anaconda3\envs\lang\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\openai\api_requestor.py:289, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#     292         params=params,
#     293         supplied_headers=headers,
#     294         files=files,
#     295         stream=stream,
#     296         request_id=request_id,
#     297         request_timeout=request_timeout,
#     298     )
#     299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File ~\anaconda3\envs\lang\Lib\site-packages\openai\api_requestor.py:606, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     604     _thread_context.session_create_time = time.time()
#     605 try:
# --> 606     result = _thread_context.session.request(
#     607         method,
#     608         abs_url,
#     609         headers=headers,
#     610         data=data,
#     611         files=files,
#     612         stream=stream,
#     613         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     614         proxies=_thread_context.session.proxies,
#     615     )
#     616 except requests.exceptions.Timeout as e:
#     617     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~\anaconda3\envs\lang\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\lang\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\lang\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File ~\anaconda3\envs\lang\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\envs\lang\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\envs\lang\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\anaconda3\envs\lang\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\envs\lang\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\lang\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\envs\lang\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\lang\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
